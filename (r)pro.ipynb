# %% [markdown]
# <a href="https://colab.research.google.com/github/saivarunmutyala/11249A240-R-Programming.LAB/blob/main/(r)pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I) Student Information System

# %%
roll_no <- 101 # Integer
name <- "VARUN" # Character
cgpa <- 8.45 # Numeric
pass <- TRUE # Logical
roll_no
name
cgpa
pass
# Out:
# [1] 101
# [1] "VARUN"
# [1] 8.45
# [1] TRUE

# %% [markdown]
# Employee Salary Record

# %%
emp_id <- 5021
salary <- 57000.72
department <- "IT"
is_permanent <- TRUE
emp_id
salary
department
is_permanent
# Out:
# [1] 5021
# [1] 57000.72
# [1] "IT"
# [1] TRUE

# %% [markdown]
# Online Shopping Cart

# %%
product_name <- "Laptop"
price <- 55000
stock_available <- 25
discount_eligible <- FALSE
product_name
price
stock_available
discount_eligible
# Out:
# [1] "Laptop"
# [1] 55000
# [1] 25
# [1] FALSE

# %% [markdown]
# Weather Monitoring System

# %%
city <- "Chennai"
temperature <- 36.5
rain <- FALSE
wind_speed <- 12.8
city
temperature
rain
wind_speed
# Out:
# [1] "Chennai"
# [1] 36.5
# [1] FALSE
# [1] 12.8

# %% [markdown]
# Examination Result Processing

# %%
subject <- "Mathematics"
total_marks <- 100
marks_obtained <- 78
result <- marks_obtained >= 40
subject
total_marks
marks_obtained
result
# Out:
# [1] "Mathematics"
# [1] 100
# [1] 78
# [1] TRUE

# %% [markdown]
# II) Loan Eligibility Check

# %%
age <- 25
income <- 35000
if(age > 21 & income > 30000){
print("Eligible for Loan")
} else {
print("Not Eligible for Loan")
}
# Out:
# [1] "Eligible for Loan"

# %% [markdown]
# Online Discount System

# %%
amount <- 4700
premium_member <- TRUE
if(amount > 5000 | premium_member){
print("Discount Applied")
} else {
print("No Discount")
}
# Out:
# [1] "Discount Applied"

# %% [markdown]
# Electricity Bill Slab

# %%
units <- 370
if(units < 100){
print("Low Usage")
} else if(units <= 300){
print("Medium Usage")
} else {
print("High Usage")
}
# Out:
# [1] "High Usage"

# %% [markdown]
# Employee Bonus Eligibility

# %%
experience <- 7
rating <- 4.5
if(experience > 5 & rating > 4){
print("Bonus Eligible")
} else {
print("Not Eligible for Bonus")
}
# Out:
# [1] "Bonus Eligible"

# %% [markdown]
# Password Validation

# %%
password <- "secure123"

if(nchar(password) >= 8){
print("Valid Password")
} else {
print("Invalid Password")
}
# Out:
# [1] "Valid Password"

# %% [markdown]
# III)  Bank Interest Calculator

# %%
simple_interest <- function(p, r, t){
si <- (p * r * t) / 100
return(si)
}
simple_interest(10000, 5, 2)
# Out:
# [1] 1000

# %% [markdown]
# Student Result Processing

# %%
check_result <- function(marks){
if(marks >= 40){
return("Pass")
} else {
return("Fail")
}
}
check_result(65)
# Out:
# [1] "Pass"

# %% [markdown]
# Employee Salary Calculation

# %%
net_salary <- function(basic_salary){
tax <- basic_salary * 0.10
net <- basic_salary - tax
return(net)
}
net_salary(30000)
# Out:
# [1] 27000

# %% [markdown]
# Electricity Bill Generator

# %%
electricity_bill <- function(units){
if(units <= 100){
bill <- units * 2
} else if(units <= 200){
bill <- (100 * 2) + (units - 100) * 3
} else {
bill <- (100 * 2) + (100 * 3) + (units - 200) * 5
}
return(bill)
}
electricity_bill(250)
# Out:
# [1] 750

# %% [markdown]
# Online Shopping Discount

# %%
final_amount <- function(amount){
if(amount >= 5000){
discount <- amount * 0.20
} else if(amount >= 2000){
discount <- amount * 0.10
} else {
discount <- 0
}
return(amount- discount)
}
final_amount(4500)
# Out:
# [1] 4050

# %% [markdown]
# IV) College Student Record System

# %%
# Student details
students <- data.frame(
RollNo = c(101, 102, 103),
Name = c("Ravi", "Meena", "Karthik"),
Dept = c("CSE", "ECE", "IT")
)
# Student marks
marks <- data.frame(
Marks = c(78, 85, 90)
)
# Join columns
student_data <- cbind(students, marks)
student_data
# Add new student records
new_students <- data.frame(
RollNo = c(104),
Name = c("Anjali"),
Dept = c("CSE"),
Marks = c(88)
)
final_data <- rbind(student_data, new_students)
final_data
# Out:
#   RollNo Name    Dept Marks
# 1 101    Ravi    CSE  78
# 2 102    Meena   ECE  85
# 3 103    Karthik IT   90
#   RollNo Name    Dept Marks
# 1 101    Ravi    CSE  78
# 2 102    Meena   ECE  85
# 3 103    Karthik IT   90
# 4 104    Anjali  CSE  88

# %% [markdown]
# Employee Management System

# %%
employee_details <- data.frame(
EmpID = c(1, 2, 3),
Name = c("Amit", "Sneha", "Raj"),
Dept = c("HR", "IT", "Finance")
)
salary_details <- data.frame(
Salary = c(35000, 45000, 50000)
)
# Join columns
employees <- cbind(employee_details, salary_details)
employees
# Add new employee
new_employee <- data.frame(
EmpID = 4,
Name = "Neha",
Dept = "IT",
Salary = 48000
)
employees <- rbind(employees, new_employee)
employees
# Out:
#   EmpID Name  Dept    Salary
# 1 1     Amit  HR      35000
# 2 2     Sneha IT      45000
# 3 3     Raj   Finance 50000
#   EmpID Name  Dept    Salary
# 1 1     Amit  HR      35000
# 2 2     Sneha IT      45000
# 3 3     Raj   Finance 50000
# 4 4     Neha  IT      48000

# %% [markdown]
# Hospital Patient Records

# %%
patient_info <- data.frame(
PatientID = c(201, 202),
Name = c("Suresh", "Lakshmi"),
Age = c(45, 38)
)
treatment_cost <- data.frame(
Cost = c(12000, 15000)
)
# Combine column-wise
patient_records <- cbind(patient_info, treatment_cost)
patient_records
# Add new patient
new_patient <- data.frame(
PatientID = 203,
Name = "Arjun",
Age = 50,
Cost = 18000
)
patient_records <- rbind(patient_records, new_patient)
patient_records
# Out:
#   PatientID Name    Age Cost
# 1 201       Suresh  45  12000
# 2 202       Lakshmi 38  15000
#   PatientID Name    Age Cost
# 1 201       Suresh  45  12000
# 2 202       Lakshmi 38  15000
# 3 203       Arjun   50  18000

# %% [markdown]
# University Academic Management System

# %%
# Student details

students <- data.frame(
RollNo = c(1, 2, 3),
Name = c("Varun", "Bina", "Charan"),
Dept = c("CSE", "ECE", "IT")
)
# Semester marks
marks <- data.frame(
Sem1 = c(78, 82, 90),
Sem2 = c(80, 85, 88)
)
# Attendance
attendance <- data.frame(
Attendance = c(92, 88, 95)
)
# Combine all columns
student_records <- cbind(students, marks, attendance)
student_records
# New admissions
new_students <- data.frame(
RollNo = c(4, 5),
Name = c("Deepa", "Eshan"),
Dept = c("CSE", "IT"),
Sem1 = c(85, 89),
Sem2 = c(87, 91),
Attendance = c(90, 93)
)
# Add rows
final_records <- rbind(student_records, new_students)
final_records
# Out:
#   RollNo Name   Dept Sem1 Sem2 Attendance
# 1 1      Varun  CSE  78   80   92
# 2 2      Bina   ECE  82   85   88
# 3 3      Charan IT   90   88   95
#   RollNo Name   Dept Sem1 Sem2 Attendance
# 1 1      Varun  CSE  78   80   92
# 2 2      Bina   ECE  82   85   88
# 3 3      Charan IT   90   88   95
# 4 4      Deepa  CSE  85   87   90
# 5 5      Eshan  IT   89   91   93

# %% [markdown]
# University Academic Management System

# %%
students <- data.frame(
RollNo = c(1, 2, 3),
Name = c("Arun", "Bina", "Charan"),
Dept = c("CSE", "ECE", "IT")
)
marks <- data.frame(
RollNo = c(1, 2, 3),
Sem1 = c(78, 82, 90),
Sem2 = c(80, 85, 88)
)
attendance <- data.frame(

RollNo = c(1, 2, 3),
Attendance = c(92, 88, 95)
)
# Merge student details and marks
student_data <- merge(students, marks, by = "RollNo")
# Merge with attendance
final_records <- merge(student_data, attendance, by = "RollNo")
final_records
# Out:
#   RollNo Name   Dept Sem1 Sem2 Attendance
# 1 1      Arun   CSE  78   80   92
# 2 2      Bina   ECE  82   85   88
# 3 3      Charan IT   90   88   95

# %% [markdown]
# Hospital Information System

# %%
patients <- data.frame(
PatientID = c(201, 202, 203),
Name = c("Suresh", "Lakshmi", "Arjun"),
Age = c(45, 38, 52)
)
diagnosis <- data.frame(
PatientID = c(201, 203),
Disease = c("Diabetes", "Cardiac")
)
billing <- data.frame(
PatientID = c(201, 202, 203),

Amount = c(15000, 12000, 25000)
)
# Merge patients with diagnosis
hospital_data <- merge(patients, diagnosis, by = "PatientID", all.x = TRUE)
# Merge with billing
hospital_data <- merge(hospital_data, billing, by = "PatientID")
hospital_data
# Out:
#   PatientID Name    Age Disease  Amount
# 1 201       Suresh  45  Diabetes 15000
# 2 202       Lakshmi 38  NA       12000
# 3 203       Arjun   52  Cardiac  25000

# %% [markdown]
# V) Employee Name Standardization

# %%
names <- c("arun", "Bala", "chitra")
upper_names <- toupper(names)
name_length <- nchar(upper_names)
upper_names
name_length
# Out:
# [1] "ARUN"   "BALA"   "CHITRA"
# [1] 4 4 6

# %% [markdown]
# Student Email Processing

# %%
emails <- c("arun@gmail.com", "meena@yahoo.com", "ravi@outlook.com")
usernames <- sub("@.*", "", emails)
usernames
# Out:
# [1] "arun"  "meena" "ravi"

# %% [markdown]
# Online Form Input Cleanup

# %%
input <- c(" R Programming ", " Data Science ", " AI ")
clean_input <- trimws(input)
clean_input
# Out:
# [1] "R Programming" "Data Science"  "AI"

# %% [markdown]
# Product Code Validation

# %%
product_codes <- c("PRD101", "PRD202", "ABC303")
valid_codes <- startsWith(product_codes, "PRD")
valid_codes
# Out:
# [1]  TRUE  TRUE FALSE

# %% [markdown]
# Password Strength Checker

# %%
password <- "secure123"
if(nchar(password) >= 8){
print("Strong Password")
} else {
print("Weak Password")
}
# Out:
# [1] "Strong Password"

# %% [markdown]
# University Student Data Cleaning System

# %%
students <- data.frame(
Name = c(" Gayathri ", "RAVI ", " meena"),
Email = c("Gayu@UNIV.edu", "ravi@univ.edu", "meena@gmail.com"),
Department = c(" cse", "ECE ", " Cse ")
)
students
# Out:
#   Name       Email           Department
# 1  Gayathri  Gayu@UNIV.edu    cse
# 2 RAVI       ravi@univ.edu   ECE
# 3  meena     meena@gmail.com  Cse

# %% [markdown]
# Product Inventory Text Cleaning

# %%
products <- data.frame(
Product = c(" apple phone ", "SAMSUNG-TV ", " dell laptop"),
Code = c("PRD-101-APL", "PRD-202-SAM", "PRD-303-DEL")
)
products$Product <- trimws(products$Product)
products$Product <- tools::toTitleCase(tolower(products$Product))
products$ProductCode <- sub("PRD-[0-9]+-", "", products$Code)
products
# Out:
#   Product     Code        ProductCode
# 1 Apple Phone PRD-101-APL APL
# 2 Samsung-Tv  PRD-202-SAM SAM
# 3 Dell Laptop PRD-303-DEL DEL

# %% [markdown]
# VI) Student Marks Processing (Vectors)

# %%
marks <- c(78, 85, 90, 88, 76)
total <- sum(marks)
average <- mean(marks)
highest <- max(marks)
total
average
highest
# Out:
# [1] 417
# [1] 83.4
# [1] 90

# %% [markdown]
# Temperature Monitoring System (Vectors)

# %%
temperature <- c(32, 33, 31, 34, 35, 36, 33)
min_temp <- min(temperature)
max_temp <- max(temperature)
min_temp
max_temp
# Out:
# [1] 31
# [1] 36

# %% [markdown]
# Employee Profile Storage (Lists)

# %%
employee <- list(
ID = 101,
Name = "Gayathri",
Salary = 45000,
Department = "IT"
)
employee
employee$Name
employee$Salary
# Out:
# $ID
# [1] 101
#
# $Name
# [1] "Gayathri"
#
# $Salary
# [1] 45000
#
# $Department
# [1] "IT"
# [1] "Gayathri"
# [1] 45000

# %% [markdown]
# College Student Database (Data Frames)

# %%
students <- data.frame(

RollNo = c(1, 2, 3),
Name = c("Anitha", "Karthik", "Meena"),
Dept = c("CSE", "ECE", "IT"),
Marks = c(85, 78, 92)
)
students
# Out:
#   RollNo Name    Dept Marks
# 1 1      Anitha  CSE  85
# 2 2      Karthik ECE  78
# 3 3      Meena   IT   92

# %% [markdown]
# VII) A retailstore maintains a CSV file sales_data.csv with the following columns:

# %%
# Create a dummy sales_data.csv for demonstration purposes
dummy_sales_data <- data.frame(
  Date = as.Date(c("2023-01-01", "2023-01-01", "2023-01-02", "2023-01-03", "2023-01-03")),
  Product = c("Laptop", "Mouse", "Keyboard", "Laptop", "Monitor"),
  Category = c("Electronics", "Electronics", "Electronics", "Electronics", "Electronics"),
  Quantity = c(2, 3, 1, 1, 2),
  Price = c(1200, 25, 75, 1200, 300)
)
write.csv(dummy_sales_data, "sales_data.csv", row.names = FALSE)

# Read the CSV file
sales <- read.csv("sales_data.csv")
# View first few rows
head(sales)
# Check structure and summary
str(sales)
summary(sales)

# Remove extra spacesin Product and Category columns
sales$Product <- trimws(sales$Product)
sales$Category <- trimws(sales$Category)
# Convert Date column to Date format
sales$Date <- as.Date(sales$Date, format="%Y-%m-%d")
# Add a column for total sales per row
sales$TotalSales <- sales$Quantity * sales$Price
# View cleaned data
head(sales)


# Calculate totalsalesfor each product
total_sales_product <- aggregate(TotalSales ~ Product, data=sales, sum)
total_sales_product

top_product <- total_sales_product[which.max(total_sales_product$TotalSales), ]
top_product

quantity_per_category <- aggregate(Quantity ~ Category, data=sales, sum)
quantity_per_category


# Products with totalsales greater than 10000
high_sales <- total_sales_product[total_sales_product$TotalSales > 10000, ]
high_sales
# Out:
#   Date       Product  Category    Quantity Price
# 1 2023-01-01 Laptop   Electronics 2        1200
# 2 2023-01-01 Mouse    Electronics 3          25
# 3 2023-01-02 Keyboard Electronics 1          75
# 4 2023-01-03 Laptop   Electronics 1        1200
# 5 2023-01-03 Monitor  Electronics 2         300
# 'data.frame':	5 obs. of  5 variables:
#  $ Date    : chr  "2023-01-01" "2023-01-01" "2023-01-02" "2023-01-03" ...
#  $ Product : chr  "Laptop" "Mouse" "Keyboard" "Laptop" ...
#  $ Category: chr  "Electronics" "Electronics" "Electronics" "Electronics" ...
#  $ Quantity: int  2 3 1 1 2
#  $ Price   : int  1200 25 75 1200 300
#      Date             Product            Category            Quantity
#  Length:5           Length:5           Length:5           Min.   :1.0
#  Class :character   Class :character   Class :character   1st Qu.:1.0
#  Mode  :character   Mode  :character   Mode  :character   Median :2.0
#                                                           Mean   :1.8
#                                                           3rd Qu.:2.0
#                                                           Max.   :3.0
#      Price
#  Min.   :  25
#  1st Qu.:  75
#  Median : 300
#  Mean   : 560
#  3rd Qu.:1200
#  Max.   :1200
#   Date       Product  Category    Quantity Price TotalSales
# 1 2023-01-01 Laptop   Electronics 2        1200  2400
# 2 2023-01-01 Mouse    Electronics 3          25    75
# 3 2023-01-02 Keyboard Electronics 1          75    75
# 4 2023-01-03 Laptop   Electronics 1        1200  1200
# 5 2023-01-03 Monitor  Electronics 2         300   600
#   Product  TotalSales
# 1 Keyboard   75
# 2 Laptop   3600
# 3 Monitor   600
# 4 Mouse      75
#   Product TotalSales
# 2 Laptop  3600
#   Category    Quantity
# 1 Electronics 9
#      Product TotalSales

# %% [markdown]
# VIII) University Course Enrollment

# %%
# Data
departments <- c("CSE", "ECE", "IT", "Mechanical")
students <- c(120, 80, 60, 40)
# Pie Chart
pie(
students,
labels = departments,
main = "Student Enrollment per Department",
col = c("skyblue", "orange", "green", "pink")
)
# Bar Chart
barplot(
students,
names.arg = departments,
main = "Number of Students per Department",
xlab = "Department",
ylab = "Number of Students",
col = c("skyblue", "orange", "green", "pink")
)
# Out:
# Plot with title “Student Enrollment per Department”
# Plot with title “Number of Students per Department”

# %% [markdown]
# Retail Store Sales Distribution

# %%
# Data
category <- c("Electronics", "Clothing", "Accessories", "Home Appliances")
sales <- c(150000, 75000, 50000, 25000)
# Pie Chart
pie(
sales,
labels = category,
main = "Sales Distribution by Category",
col = rainbow(length(category))
)
# Bar Chart
barplot(
sales,
names.arg = category,
main = "Sales per Category",
xlab = "Category",
ylab = "Sales (₹)",
col = rainbow(length(category))
)
# Out:
# Plot with title “Sales Distribution by Category”
# Plot with title “Sales per Category”

# %%
#IX) School Student Marks Analysis

# %%
# Step 1: Create dataset
students <- data.frame(
Name =
c("Arjun","Meena","Rahul","Anitha","Kiran","Sneha","Ravi","Gayathri","Suresh","Lakshmi"),
Maths = c(85,90,70,95,80,88,75,92,68,86),
Science = c(78,88,60,92,85,80,70,90,75,82),
English = c(92,80,75,98,88,85,78,91,80,87)
)
# Step 2: Mean, Median, SD
mean_marks <- sapply(students[ ,2:4], mean)
median_marks <-sapply(students[ ,2:4], median)
sd_marks <- sapply(students[ ,2:4], sd)
# Step 3: Total marks per student
students$Total <- rowSums(students[ ,2:4])
top_student <- students[which.max(students$Total), ]
# Step 4: Students above average in Maths
avg_math <- mean(students$Maths)
above_avg_math <- students[students$Maths > avg_math, ]
mean_marks
median_marks
sd_marks
top_student
above_avg_math
# Out:
#   Maths Science English
#    82.9    80.0    85.4
#   Maths Science English
#    85.5    81.0    86.0
#    Maths  Science  English
# 9.302927 9.809293 7.183314
#   Name   Maths Science English Total
# 4 Anitha 95    92      98      285
#    Name     Maths Science English Total
# 1  Arjun    85    78      92      255
# 2  Meena    90    88      80      258
# 4  Anitha   95    92      98      285
# 6  Sneha    88    80      85      253
# 8  Gayathri 92    90      91      273
# 10 Lakshmi  86    82      87      255

# %% [markdown]
# Hospital Patient Age Analysi

# %%
# Dataset
patients <- data.frame(
PatientID = 201:210,
Name = c("Suresh","Lakshmi","Arjun","Meena","Ravi","Anitha","Kiran","Sneha","Gayathri","Ravi2"),
Age = c(45,38,52,29,60,48,55,35,42,50)
)
# Statistical analysis
mean_age <- mean(patients$Age)
median_age <- median(patients$Age)
range_age <- range(patients$Age)
sd_age <- sd(patients$Age)
# Patients older than 50
older_patients <- patients[patients$Age > 50, ]
mean_age
median_age
range_age
sd_age
older_patients
# Out:
# [1] 45.4
# [1] 46.5
# [1] 29 60
# [1] 9.547542
#   PatientID Name  Age
# 3 203       Arjun 52
# 5 205       Ravi  60
# 7 207       Kiran 55
